# %%
# Mount Drive files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 8.2 MB/s eta 0:00:00
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 34.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 56.7 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelForSequenceClassification

model_es = AutoModelForSequenceClassification.from_pretrained(f"/content/drive/MyDrive/Colab Notebooks/dl4nlp_labs/final_project/sentence_similarity/models/spanish/checkpoint-356")
model_en = AutoModelForSequenceClassification.from_pretrained(f"/content/drive/MyDrive/Colab Notebooks/dl4nlp_labs/final_project/sentence_similarity/models/english/checkpoint-4180")
model_multilingual = AutoModelForSequenceClassification.from_pretrained(f"/content/drive/MyDrive/Colab Notebooks/dl4nlp_labs/final_project/sentence_similarity/models/multilingual/checkpoint-801")


model_es.push_to_hub("nflechas/spanish-BERT-sts")
model_en.push_to_hub("nflechas/english-BERT-sts")
model_multilingual.push_to_hub("nflechas/spanish-multilingualBERT-sts")
# Out:
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# ...
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# pytorch_model.bin:   0%|          | 0.00/711M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/nflechas/spanish-multilingualBERT-sts/commit/4cfac729f4e7cc7fb9e8a930f6fc5425d47b20d1', commit_message='Upload BertForSequenceClassification', commit_description='', oid='4cfac729f4e7cc7fb9e8a930f6fc5425d47b20d1', pr_url=None, pr_revision=None, pr_num=None)
